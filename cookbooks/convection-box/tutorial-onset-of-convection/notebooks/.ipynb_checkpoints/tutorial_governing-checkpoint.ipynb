# %% [markdown]
# ### <img src="static/aspect_www_small.jpg" style="display: inline-block; width: 150px; padding-right:25px" align=left />
#
#
# # Introduction to ASPECT
# This is a demonstration notebook to show how to run ASPECT in a Jupyter notebook. <br>
#
# This notebook has been verified to run with ASPECT-Jupyter Notebooks tool running in a JupyerLab environment found on:
# https://geodynamics.org/resources/aspectnotebook
#
# With the current dependencies
# * Python 3.8.5
# * IPython 7.19.0
# * Jupyterlab 3.2.1
# * Jupyter widget extension 1.0.0 (see Appendix B)
# * matplotlib 3.3.2
# * numpy 1.19.2
# * tables
# * ipympl
# * scipy
# * glob
# * docker (optional)
#
#
# To complete all exercises, you will also need:
# * ParaView
#
# By completing this notebook, you will learn how to:
# > Run ASPECT from the command line within a notebook environment.
#
# > Understand the basic layout of a .prm file used to control ASPECT simulations.
#
# > Plot simple output statistics and create files that are viewable in ParaView (and Visit).
#
# > Explore the Nusselt-Rayleigh number relationship.
#
# ASPECT is an open source community project. As such, we encourage contributions from the community to improve this code over time.
#
# **Principal Developers:** Jacky Austermann,
# Wolfgang Bangerth,
# Juliane Dannberg,
# Menno Fraters,
# Rene Gassmoeller,
# Anne Glerum,
# Timo Heister,
# Bob Myhill,
# John Naliboff, and
# Cedric Thieulot.<br>
# **Notebook Authors:** Lorraine J. Hwang and Ian Rose with tutorial material from Juliane Dannberg<br>
# **ASPECT forum:** http://lists.geodynamics.org/cgi-bin/mailman/listinfo/aspect-devel <br>
# **github repository:** https://github.com/geodynamics/aspect<br>
# **website:** https://aspect.geodynamics.org/
#
# ### Release Notes
#
# **2017**
#
# Updates instructions for running in the CIG sandbox.
#
# **October 2023** <br>
# This version has been updated to run on the notebook server on geodynamics.org maintained by HUBzero.
# and is no longer compatible with the docker container mentioned in Appendix A due to changes in the .prm file.
# <p>With modifications you should be able to run this on a native install. </p>
#
# ---
#
# ## 1 Introduction to ASPECT
#
# ASPECT — the Advanced Solver for Planetary Evolution, Convection, and Tectonics — is a parallel finite element code intended to solve the equations that describe thermally driven convection with a focus on doing so in the context of convection
# in the earth's mantle.
# It has grown from a pure
# mantle-convection code into a tool for many geodynamic applications
# including applications for inner core convection, lithospheric scale
# deformation, two-phase flow, and numerical methods development.
#
# The code builds on the deal.II library (https://www.dealii.org/), and, through deal.II, on Trilinos (see http://trilinos.org/) for parallel linear algebra and on p4est (see http://www.p4est.org/) for parallel mesh handling.
#
# **Modularity**
#
# ASPECT is designed to be an extensible code. It uses both a plug in architecture and a set of signals in which you can replace or extend certain parts of the code. The most common modifications made are changes to the material model, geometry, the direction and magnitude of gravity, and/or the initial and boundary conditions; and additions of postprocesors.  To make these this as a simple as possible, parts of the program have been separated into modules that communicate through interfaces.
#
# For more information, consult the manual, section <em> 6.0 Extending ASPECT</em>.
#
# <img src="static/modularity1.png" style="display: inline-block;width: 475px; padding-right:25px; padding-left:25px"> <img src="static/modularity2.png" style="display: inline-block; width: 450px; padding-left:25px">
#
# Skip to Section 4 for information on:
# > 4.1 Governing Equations
#
# > 4.2 The .prm File
#
# > 4.3 Default Values
#
#
# ## 2.0 Running ASPECT
#
# ### 2.1 I/O
#
# ASPECT takes as input parameter files (\*.prm) that completely describes your simulation. The parameter files determines the discretization, intial conditions, boundary conditions, material model, etc. See [Parameter Documentation](https://aspect-documentation.readthedocs.io/en/latest/parameters/index.html) in the manual for the complete list of run-time input parameters.
#
# Example .prm files can be found in the cookbooks/ and benchmarks/ directory of the ASPECT distribution.
# If you are running this from ASPECT Jupyter Notebooks on geodynamics.org, then ASPECT example models and data are located in directories defined in the environment variables `$ASPECT_DIR` and `$ASPECT_SOURCE_DIR`.
#
# ### 2.2 Convection in a 2-D Box
#
# Before beginning, create a working directory or folder for your model input .prm files, e.g., 'model_input'.
# Use the Jupyterlab file browser to add the new folder.
#
# Copy the following files into the folder:
# * convection-box.prm
# * convection-box2.prm
# * tutorial.prm
#
# Let's verify this first:
#
# > **Step 1:** Check which directory you are currently in.
#
# > **Step 2:** Print a list of its contents. Verfiy that the folder model_input exists.
#
# **Tip:** "!" indicates a bash command.
#
# **Shortcut:** $<$shift$>$$<$enter$>$ will execute your current cell.

# %%
# !pwd
# !ls
# Out:
# /home/geodynamics/ljhwang/ASPECT-Jupyter/Notebook
# ASPECT_Jupyter.ipynb  modularity1.png  output-convection-box2  TempInit.jpg
# aspect_www_small.jpg  modularity2.png  TempFinal.jpg

# %% [markdown]
# > **Step 3:** Confirm that the cookbooks are in your path.

# %%
# !ls $ASPECT_DIR/cookbooks/convection-box
# Out:
# convection-box.prm  doc

# %%
Simulation output will be store in the directory "output" or as specified in the input .prm file:

        set Output directory = output-convection-box
        

Review the file convection-box.prm to familiarize yourself with its contents and its input parameters:

>**Exercise**: How many Dimensions is this problem?       
   <blockquote> A: 2 specifies a two dimensional problem  </blockquote>

>**Exercise**: How long, in model time, will the simulation run?
    <blockquote> A: 0.5 years </blockquote>   

While in your working directory 'ModelInput', you then launched the docker container mapping your current working directory to model_input.

# %% [markdown]
# Next:
# > **Step 1:** Change your directory to 'aspect'.
#
# > **Step 2:** Check whether your .prm file is in the directory model_input.
#
# **Note:** To change directories you must import the python interpreter.
#
# **Shortcut:** You can always check the contents of your directory through the Jupyter notebook browser.

# %%
import os
# HUB: aspect is already in the container default path. No need to change directories.
#os.chdir('aspect')
os.chdir('..')
# !ls model_input
# Out:
# convection-box2-old.prm  convection-box_old.prm  tutorial.prm
# convection-box2.prm	 convection-box.prm	 Untitled.ipynb

# %% [markdown]
# ### 2.3 Executing ASPECT
#
# Run ASPECT by calling the code specifing the input parameter file.
#
# The exectable is located one directory above your location. Always make sure your paths are correct relative to your current working directory.
#
# When you start ASPECT, the code will print information about your run:
# > **Exercise:** What version number are you running?
#
# > **Exercise:** Are you running in debug or optimized mode?
#
# > **Exercise:** How many mpi processes are running?
#
# > **Exercise:** Which solver are you using - Trilinos or PETSc?
#
# The code will run in a scrollable window.  Scroll to monitor code progress and eventually to the end of the screen output.
#
# **Tip:** You may save this information along with this entire notebook any time by selecting from the toolbar: File > Download as > (option)
#
# **Tip:** In [$*$] indicates that the code is running.  When finished, the '$*$' will be replaced by a number.

# %%
# HUB: aspect is already in the container default path. No need to change directories.
# This version of the .prm choose to use the Boussinesq approximation.
# NOTE TO SELF TO UPLOAD this .prm
#!./aspect model_input/convection-box.prm
# !aspect model_input/convection-box.prm

# %% [markdown]
# ### 2.4 Output Files
#
# Output files are written to the directory as specified in your .prm file.  If you did not change this, the directory will be 'output'.
#
# > ** Exercise:** What files do you see?
#
# >  ** Exercise:** What values are stored in 'output/statistics' ?
#
# >  ** Exercise:** What is the surface heat flux at the end of the run?
#
# #### Downloading FIles
#
# To move the files out of the container onto your desktop, you will create and download a zip file:
#
# > **Step 1:**  Navigate to the notebook browser window.
#
# > **Step 2:**  Start a new terminal window : New > Terminal
#
# > **Step 3:**  In your terminal window, create a compressed tarball of the directory, where 'output.tar.gz' is your target file and 'ouput' is your input folder.
#
# >          cd aspect
# >          tar zcfv output.tar.gz output
#
# > **Step 4:**  From your notebook browser window, select the checkbox next to your output.tar.gz file and then click 'Download'
#
# **Note:** Jupyter does not support downloading more than one file at once and does not allow you to download directories.
#
# ### 2.5 Plotting Statistics
#
# If you have downloaded the output files, use your favorite method to plot simulation time vs. heat flux through the top boundary.  This is columns 2 and 20 in the outout file 'statistics'.
#
# OR
#
# Plot in this notebook:
#
# > **Step 1:** Check to make sure the directory and file exists.

# %%
#NOTE TO SELF: Change this path and the file path for plotting
# !ls output-convection-box

# %% [markdown]
# > **Step 2:**  Run the cell below to see what this should look like.
#
# > **Exercise:** Modify the python code to look at flow through the other boundaries.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from matplotlib.ticker import FormatStrFormatter

# %matplotlib inline

#I'm throwing away the filename as all I care about is column 2 and 20
data = np.genfromtxt('output-convection-box/statistics',autostrip=True)

#check this read. It seems to work!
#print (y[1], y[19])
print (data[:,1])

#ok now let's see if we can plot it
fig = plt.figure( figsize = (10,5))
ax = fig.add_subplot(111)
ax.set_ylim([0., 10.0])

ax.plot(data[:,1],data[:,19],linewidth=2.0)
   
plt.show()

# %% [markdown]
# ### 2.6 Visualization in ParaView
#
# ParaView is an open-source, multi-platform data analysis and visualization application available from:
#
#     http://www.paraview.org/
#
# ParaView was developed to analyze extremely large datasets using distributed memory computing resources. It can be run on supercomputers to analyze datasets of petascale size as well as on laptops for smaller data. It supports visualization tools such as isosurfaces, slices, streamlines, volume rendering, and othe complex visualization techniques.
#
# ParaView is not supported in Jupyter notebooks and must be launched from your desktop. Please see separate tutorial to learn how to use Paraview.
#
# If you are running this notebook within a docker container, you must download the output files to use ParaView. Default location is in the 'output' folder. See Section 2.4 for instructions to download files.
#
# **Tip:** ParaView files have the file extension .pvtu. ParaView data files have the file extension .pvd.
#
#
# <img src="TempInit.jpg" style="display: inline-block;width: 50%; padding-right:25px; padding-left:105px"> <img src="TempFinal.jpg" style="display: inline-block; width: 40%; padding-left:25px"/1>
#
# <center> Convection in a box: Initial temperature (left) and final state (right). Input file: convection-box.prm
# </center>
# <br>
# **Exercise:**  Reproduce the above plots in ParaView produced from the output files of convection-box.prm.
#
# <em>Note: You will no longer be working inside the Notebook and/or container for this exercise.</em>
# >**Step 1:** Download your 'output' folder.  See Section 2.4.
#
# >**Step 2:** Launch ParaView.
#
# >**Step 3:** Open your .pvd file, e.g. solution.pvd.
# >The file will contain temperature (<em>T</em>), pressure (<em>P</em>), and velocity.
#
# > **Exercise:** Can you find where this was specified in the .prm file?<br>
# >> **Tip:** Look for:
#
# >>        subsection Postprocess
#
#
# >**Step 4:** Visualize the <em>T</em> field.
# >> **Tip:** In the Properties panel, change from <em>Solid Color</em> to <em>T</em>.
#
# >**Step 4:** Visulize how <em>T</em> changes through time.
#
# >> **Tip:** Select the play button on the toolbar.
#
#
# > **Exercise:** Try switiching paramenters, playing with color scales, and switching to other views!

# %% [markdown]
# ### 2.7 Visualizing Heat flux
#
# There are fun ways to visualize time varying parameters using sliders.
#
# To do this we will rerun ASPECT with a convection-box2.prm file that will create hdf5 files.
#
# > **Exercise:** What is the difference between convection-box2.prm and convection-box.prm?
#
# ** Note: ** hdf5 is the Hierarchical Data Format (HDF) is a set of file formats designed to store and organize large amounts of data developed at NCSDA and is freely available under an BSD-style open source license.
#
# > ** Step 1: ** Run ASPECT with the file convection-box2.prm as input.
#
# ** Tip: ** Don't be afraid to cut and paste from previous cells to rerun ASPECT but do make sure you change the name of the input file.

# %%
#!./aspect model_input/convection-box2.prm
# !aspect model_input/convection-box2.prm

# %% [markdown]
# > **Step 2:** Check to see where your hdf5 files are.
# >> **Exercise:** How many files are there?

# %%
#!ls output-convection-box2/solution
# !pwd

# %% [markdown]
# > **Step 3:** Run the visualization code in the next cell.
# >> **Exercise:** Can you guess what it will plot?
#
# >> **Exercise:** How many files are you reading in?
#
# >> **Exercise:** Play with the sliders!
#
# ** Debug:** If your laptop does not have a lot of memory, you will not be able to read in all the files. You will need to modify the code below. Uncomment the 'for' (line 17) statement and select the files you want to read. Do not forget to comment out the corresponding 'for' (line 19).
# <br>

# %%
# Author: Ian Rose 16 May 2017
#not all imports are necessary but sometimes I start in the middle of the notebook ... whoops.
#this script may generate a nonfatal error (Notebook validation error) that has been reported to the Jupyter group
import ipywidgets
import matplotlib.pyplot as plt
import numpy as np
import glob
import tables
import scipy.interpolate as interpolate
# Import these 2 to work in Jupyter
#%matplotlib notebook
#%matplotlib inline
# Import this one to work with Jupyterlab
# %matplotlib widget

# Load the visualization output files
viz_files = sorted(glob.glob('output-convection-box2/solution/solution*.h5'))
viz_data = []
mesh_x, mesh_y = np.meshgrid(np.linspace(0., 1., 100), np.linspace(0,1, 100))
#If you have limited memory, you may want to choose the number of timesteps read. The following line sets it to 99.
for fname in viz_files[:99]:
#read in all the files. Comment this out if you have limited memory.
#for fname in viz_files:
    mesh = tables.open_file('output-convection-box2/solution/mesh-00000.h5', mode='r')
    fields = tables.open_file(fname, mode='r')
    nodes = mesh.root.nodes
    field = getattr(fields.root, 'T')
    coords = np.array([x for x in nodes])
    values = np.array([t for t in field])[:,0]
    fn = interpolate.LinearNDInterpolator(coords,values)
    viz_data.append(fn(mesh_x,mesh_y))
    
# Get the heat flux output files
flux_files = sorted(glob.glob('output-convection-box2/heat_flux.*'))
flux_data = []
#Comment these lines like above for limited memory computers.
#for fname in flux_files[:99]:
for fname in flux_files:
    data = np.loadtxt(fname, skiprows=1)
    indices = np.where(data[:,1]>0.99)
    flux_data.append( *list(zip(data[indices,0], data[indices,2])))
    
# Create the figure
fig = plt.figure(num='Heat flux through the top surface', figsize=(10,8))
ax1 = fig.add_subplot(211)
line, = ax1.plot(flux_data[0][0],flux_data[0][1])
ax1.set_xlim(0., 1.)
ax1.set_ylim(0., 8.)
ax1.set_ylabel('Heat flux')
ax1.xaxis.set_visible(False)

ax2 = fig.add_subplot(212)
ax2.xaxis.set_visible(False)
ax2.yaxis.set_visible(False)

image = ax2.pcolormesh(viz_data[0], cmap='RdYlBu_r')
fig.subplots_adjust(hspace=0)

@ipywidgets.interact(timestep=(0, len(viz_data)-1))
def update_plot(timestep):
    line.set_data(flux_data[timestep][0], flux_data[timestep][1])
    image.set_array(viz_data[timestep].ravel())

# %% [markdown]
# ## 3.0 Nusselt-Rayleigh Number Relationship
#
# ** If the Rayleigh number goes up, how does the Nusselt number change?**
#
# ** How does the mesh resolution affect the accuracy of these results? **
#
# In this exercise, ASPECT is used to study the relationship between the Rayleigh ($Ra$) number and the surface heat flux. In geodynamics, the Rayleigh number indicates the presence and strength of convection in the mantle. The Nusselt ($Nu$) number is the ratio of convective to conductive heat transfer.
#
# $Ra$ is related to viscosity ($\eta$) through the following relationship:
#
# \begin{align}
#   Ra = {{ \rho_0 g \alpha \Delta T D^3 } \over {\eta \kappa}}
# \end{align}
#
# \begin{align}
#   \eta = {{ \rho_0 g \alpha \Delta T D^3 } \over {\kappa Ra} }
# \end{align}
#
# \begin{align}
#   = {{5.0993 x 10^{28}} \over {Ra} }
# \end{align}
#
#
# The Nusselt number is the ratio of convective to conductive heat transfer and is related to the heat flux.
#
# Select from the table a refinement level, end time, and Rayleigh number.
#
# | Ra        | 4000 | 20000 | 100000 | 500000 |
# |-----------|------|-------|--------|--------|
# | end time  |  1.000e+12 |  2.000e+11 | 3.000+10   |  5.000e+09 |
# | viscosity |  1.275e+25 |  2.550e+24 | 5.099e+23  |  1.020e+23 |
# | Refine 3  | | | | |
# | Refine 4  | | | | |
# | Refine 5  | | | | | |
#
# > **Step 1:** From your desktop, modify the tutorial.prm file according to your selection.
#
# > * end time is part of the General parameters:
#         set End time
#
# > * viscosity is part of:
#         subsection Material model
#
# > * Refine is part of:
#         subsection Mesh refinement
#
# > **Step 2:** Run ASPECT.
#
# > **Step 3: **Keep track of the heat flux number at the top boundary (boundary 3) and populate the above table.
# >> **HINT:** Look in the file 'statistics' or the output to the terminal window.
#
# **WARNING:** higher refinement levels and higher $Ra$ numbers require longer computational time and may take a long time to complete on most computers running with 1 mpi process.

# %%
# !aspect model_input/tutorial.prm
# Out:
# -----------------------------------------------------------------------------
# -- This is ASPECT, the Advanced Solver for Problems in Earth's ConvecTion.
# --     . version 2.5.0-pre
# --     . using deal.II 9.4.0
# --     .       with 32 bit indices and vectorization level 1 (128 bits)
# --     . using Trilinos 12.18.1
# --     . using p4est 2.3.2
# --     . running in DEBUG mode
# --     . running with 1 MPI process
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=2.5.0-pre&particles=1&sha=d9396f92f&src=code
# -----------------------------------------------------------------------------
# Number of active cells: 64 (on 4 levels)
# Number of degrees of freedom: 948 (578+81+289)
#
# *** Timestep 0:  t=0 years, dt=0 years
#    Solving temperature system... 0 iterations.
#    Rebuilding Stokes preconditioner...
#    Solving Stokes system... 5+0 iterations.
#
#    Postprocessing:
#
#      Model domain depth (m):                        3e+06
#      Temperature contrast across model domain (K):  3327
#      Reference depth (m):                           0
#      Reference temperature (K):                     0
#      Reference pressure (Pa):                       0
#      Reference gravity (m/s^2):                     9.81
#      Reference density (kg/m^3):                    3319.34
#      Reference thermal expansion coefficient (1/K): 2e-05
#      Reference specific heat capacity (J/(K*kg)):   1250
#      Reference thermal conductivity (W/(m*K)):      4.7
#      Reference viscosity (Pa*s):                    5.099e+23
#      Reference thermal diffusivity (m^2/s):         1.13276e-06
#      Rayleigh number:                               101285
#
#      RMS, max velocity:                  0.000234 m/year, 0.00038 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.189e+04 W, 2.189e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00000
#      Writing particle output:            output-tutorial/particles/particles-00000
#
# *** Timestep 1:  t=4.9254e+08 years, dt=4.9254e+08 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 10+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00123 m/year, 0.002 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.239e+04 W, 2.241e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00001
#      Writing particle output:            output-tutorial/particles/particles-00001
#
# *** Timestep 2:  t=5.86163e+08 years, dt=9.36225e+07 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00225 m/year, 0.00366 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.336e+04 W, 2.338e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00002
#      Writing particle output:            output-tutorial/particles/particles-00002
#
# *** Timestep 3:  t=6.37285e+08 years, dt=5.11221e+07 years
#    Solving temperature system... 13 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00329 m/year, 0.00536 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.478e+04 W, 2.48e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00003
#      Writing particle output:            output-tutorial/particles/particles-00003
#
# *** Timestep 4:  t=6.7222e+08 years, dt=3.4935e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0043 m/year, 0.00701 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.672e+04 W, 2.674e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00004
#      Writing particle output:            output-tutorial/particles/particles-00004
#
# *** Timestep 5:  t=6.98932e+08 years, dt=2.67124e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00526 m/year, 0.00858 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.918e+04 W, 2.92e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00005
#      Writing particle output:            output-tutorial/particles/particles-00005
#
# *** Timestep 6:  t=7.20759e+08 years, dt=2.18271e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00616 m/year, 0.01 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.221e+04 W, 3.223e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00006
#      Writing particle output:            output-tutorial/particles/particles-00006
#
# *** Timestep 7:  t=7.39393e+08 years, dt=1.86338e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00698 m/year, 0.0114 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.587e+04 W, 3.59e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00007
#      Writing particle output:            output-tutorial/particles/particles-00007
#
# *** Timestep 8:  t=7.55806e+08 years, dt=1.64125e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00774 m/year, 0.0127 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -4.025e+04 W, 4.028e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00008
#      Writing particle output:            output-tutorial/particles/particles-00008
#
# *** Timestep 9:  t=7.70607e+08 years, dt=1.48016e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00842 m/year, 0.0138 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -4.545e+04 W, 4.551e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00009
#      Writing particle output:            output-tutorial/particles/particles-00009
#
# *** Timestep 10:  t=7.84208e+08 years, dt=1.36012e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00902 m/year, 0.0148 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -5.163e+04 W, 5.173e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00010
#      Writing particle output:            output-tutorial/particles/particles-00010
#
# *** Timestep 11:  t=7.96901e+08 years, dt=1.26922e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00954 m/year, 0.0156 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -5.897e+04 W, 5.913e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00011
#      Writing particle output:            output-tutorial/particles/particles-00011
#
# *** Timestep 12:  t=8.089e+08 years, dt=1.19996e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00999 m/year, 0.0163 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -6.765e+04 W, 6.791e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00012
#      Writing particle output:            output-tutorial/particles/particles-00012
#
# *** Timestep 13:  t=8.20374e+08 years, dt=1.14742e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0104 m/year, 0.0169 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -7.79e+04 W, 7.828e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00013
#      Writing particle output:            output-tutorial/particles/particles-00013
#
# *** Timestep 14:  t=8.31457e+08 years, dt=1.1083e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0106 m/year, 0.0174 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -8.989e+04 W, 9.043e+04 W
#      Writing graphical output:           output-tutorial/solution/solution-00014
#      Writing particle output:            output-tutorial/particles/particles-00014
#
# *** Timestep 15:  t=8.42261e+08 years, dt=1.08033e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0109 m/year, 0.0177 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.038e+05 W, 1.045e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00015
#      Writing particle output:            output-tutorial/particles/particles-00015
#
# *** Timestep 16:  t=8.5288e+08 years, dt=1.06195e+07 years
#    Solving temperature system... 14 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.011 m/year, 0.0178 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.199e+05 W, 1.208e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00016
#      Writing particle output:            output-tutorial/particles/particles-00016
#
# *** Timestep 17:  t=8.63401e+08 years, dt=1.05212e+07 years
#    Solving temperature system... 13 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.011 m/year, 0.0179 m/year
#      Temperature min/avg/max:            273 K, 1937 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.378e+05 W, 1.389e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00017
#      Writing particle output:            output-tutorial/particles/particles-00017
#
# *** Timestep 18:  t=8.73895e+08 years, dt=1.04937e+07 years
#    Solving temperature system... 13 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.011 m/year, 0.0178 m/year
#      Temperature min/avg/max:            270.6 K, 1937 K, 3602 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.569e+05 W, 1.583e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00018
#      Writing particle output:            output-tutorial/particles/particles-00018
#
# *** Timestep 19:  t=8.84423e+08 years, dt=1.05277e+07 years
#    Solving temperature system... 13 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.011 m/year, 0.0176 m/year
#      Temperature min/avg/max:            265.5 K, 1937 K, 3607 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.774e+05 W, 1.789e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00019
#      Writing particle output:            output-tutorial/particles/particles-00019
#
# *** Timestep 20:  t=8.95058e+08 years, dt=1.06356e+07 years
#    Solving temperature system... 13 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0108 m/year, 0.0173 m/year
#      Temperature min/avg/max:            260.5 K, 1937 K, 3612 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.989e+05 W, 2.006e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00020
#      Writing particle output:            output-tutorial/particles/particles-00020
#
# *** Timestep 21:  t=9.05876e+08 years, dt=1.08181e+07 years
#    Solving temperature system... 13 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0106 m/year, 0.0169 m/year
#      Temperature min/avg/max:            255.9 K, 1937 K, 3617 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.212e+05 W, 2.231e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00021
#      Writing particle output:            output-tutorial/particles/particles-00021
#
# *** Timestep 22:  t=9.16955e+08 years, dt=1.10785e+07 years
#    Solving temperature system... 13 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0103 m/year, 0.0164 m/year
#      Temperature min/avg/max:            251.5 K, 1936 K, 3621 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.439e+05 W, 2.458e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00022
#      Writing particle output:            output-tutorial/particles/particles-00022
#
# *** Timestep 23:  t=9.28378e+08 years, dt=1.14228e+07 years
#    Solving temperature system... 13 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.01 m/year, 0.0158 m/year
#      Temperature min/avg/max:            247.4 K, 1936 K, 3625 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.665e+05 W, 2.685e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00023
#      Writing particle output:            output-tutorial/particles/particles-00023
#
# *** Timestep 24:  t=9.40238e+08 years, dt=1.18599e+07 years
#    Solving temperature system... 13 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00965 m/year, 0.0151 m/year
#      Temperature min/avg/max:            243.4 K, 1936 K, 3629 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.885e+05 W, 2.905e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00024
#      Writing particle output:            output-tutorial/particles/particles-00024
#
# *** Timestep 25:  t=9.5264e+08 years, dt=1.24023e+07 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00923 m/year, 0.0143 m/year
#      Temperature min/avg/max:            239.3 K, 1936 K, 3633 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.091e+05 W, 3.11e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00025
#      Writing particle output:            output-tutorial/particles/particles-00025
#
# *** Timestep 26:  t=9.65707e+08 years, dt=1.30675e+07 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00876 m/year, 0.0135 m/year
#      Temperature min/avg/max:            235 K, 1936 K, 3637 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.275e+05 W, 3.292e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00026
#      Writing particle output:            output-tutorial/particles/particles-00026
#
# *** Timestep 27:  t=9.79586e+08 years, dt=1.38788e+07 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00825 m/year, 0.0128 m/year
#      Temperature min/avg/max:            230.5 K, 1936 K, 3641 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.44e+05 W, 3.456e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00027
#      Writing particle output:            output-tutorial/particles/particles-00027
#
# *** Timestep 28:  t=9.9415e+08 years, dt=1.45638e+07 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00772 m/year, 0.0123 m/year
#      Temperature min/avg/max:            225.7 K, 1936 K, 3646 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.58e+05 W, 3.595e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00028
#      Writing particle output:            output-tutorial/particles/particles-00028
#
# *** Timestep 29:  t=1.00927e+09 years, dt=1.5122e+07 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00718 m/year, 0.0117 m/year
#      Temperature min/avg/max:            220.6 K, 1936 K, 3650 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.691e+05 W, 3.704e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00029
#      Writing particle output:            output-tutorial/particles/particles-00029
#
# *** Timestep 30:  t=1.02507e+09 years, dt=1.57958e+07 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00663 m/year, 0.0112 m/year
#      Temperature min/avg/max:            212.7 K, 1936 K, 3658 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.772e+05 W, 3.782e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00030
#      Writing particle output:            output-tutorial/particles/particles-00030
#
# *** Timestep 31:  t=1.04167e+09 years, dt=1.66035e+07 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00608 m/year, 0.0105 m/year
#      Temperature min/avg/max:            207.7 K, 1936 K, 3663 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.823e+05 W, 3.83e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00031
#      Writing particle output:            output-tutorial/particles/particles-00031
#
# *** Timestep 32:  t=1.05924e+09 years, dt=1.75684e+07 years
#    Solving temperature system... 12 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00554 m/year, 0.00986 m/year
#      Temperature min/avg/max:            202.8 K, 1936 K, 3667 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.846e+05 W, 3.851e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00032
#      Writing particle output:            output-tutorial/particles/particles-00032
#
# *** Timestep 33:  t=1.07796e+09 years, dt=1.87193e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00501 m/year, 0.00917 m/year
#      Temperature min/avg/max:            195 K, 1936 K, 3674 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.844e+05 W, 3.847e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00033
#      Writing particle output:            output-tutorial/particles/particles-00033
#
# *** Timestep 34:  t=1.09805e+09 years, dt=2.00911e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0045 m/year, 0.00848 m/year
#      Temperature min/avg/max:            185.9 K, 1935 K, 3682 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.819e+05 W, 3.819e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00034
#      Writing particle output:            output-tutorial/particles/particles-00034
#
# *** Timestep 35:  t=1.11977e+09 years, dt=2.1719e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.004 m/year, 0.00779 m/year
#      Temperature min/avg/max:            175.7 K, 1935 K, 3692 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.773e+05 W, 3.77e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00035
#      Writing particle output:            output-tutorial/particles/particles-00035
#
# *** Timestep 36:  t=1.14335e+09 years, dt=2.35849e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00354 m/year, 0.00711 m/year
#      Temperature min/avg/max:            164.8 K, 1935 K, 3702 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.707e+05 W, 3.701e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00036
#      Writing particle output:            output-tutorial/particles/particles-00036
#
# *** Timestep 37:  t=1.16913e+09 years, dt=2.57711e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0031 m/year, 0.00645 m/year
#      Temperature min/avg/max:            154.9 K, 1935 K, 3711 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.623e+05 W, 3.615e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00037
#      Writing particle output:            output-tutorial/particles/particles-00037
#
# *** Timestep 38:  t=1.19744e+09 years, dt=2.83132e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0027 m/year, 0.00583 m/year
#      Temperature min/avg/max:            147.3 K, 1935 K, 3718 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.524e+05 W, 3.513e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00038
#      Writing particle output:            output-tutorial/particles/particles-00038
#
# *** Timestep 39:  t=1.22869e+09 years, dt=3.12475e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00233 m/year, 0.00524 m/year
#      Temperature min/avg/max:            143.7 K, 1934 K, 3721 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.413e+05 W, 3.4e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00039
#      Writing particle output:            output-tutorial/particles/particles-00039
#
# *** Timestep 40:  t=1.26329e+09 years, dt=3.46072e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00201 m/year, 0.00472 m/year
#      Temperature min/avg/max:            146.3 K, 1934 K, 3717 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.291e+05 W, 3.276e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00040
#      Writing particle output:            output-tutorial/particles/particles-00040
#
# *** Timestep 41:  t=1.30171e+09 years, dt=3.8417e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00173 m/year, 0.00423 m/year
#      Temperature min/avg/max:            157.8 K, 1934 K, 3705 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.161e+05 W, 3.144e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00041
#      Writing particle output:            output-tutorial/particles/particles-00041
#
# *** Timestep 42:  t=1.34444e+09 years, dt=4.27272e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00149 m/year, 0.0038 m/year
#      Temperature min/avg/max:            179.6 K, 1934 K, 3683 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -3.026e+05 W, 3.008e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00042
#      Writing particle output:            output-tutorial/particles/particles-00042
#
# *** Timestep 43:  t=1.39185e+09 years, dt=4.74139e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00129 m/year, 0.00342 m/year
#      Temperature min/avg/max:            211.5 K, 1933 K, 3651 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.887e+05 W, 2.869e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00043
#      Writing particle output:            output-tutorial/particles/particles-00043
#
# *** Timestep 44:  t=1.44413e+09 years, dt=5.22818e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00112 m/year, 0.00311 m/year
#      Temperature min/avg/max:            250.5 K, 1933 K, 3612 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.749e+05 W, 2.731e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00044
#      Writing particle output:            output-tutorial/particles/particles-00044
#
# *** Timestep 45:  t=1.50153e+09 years, dt=5.73944e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000992 m/year, 0.00284 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.614e+05 W, 2.597e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00045
#      Writing particle output:            output-tutorial/particles/particles-00045
#
# *** Timestep 46:  t=1.56415e+09 years, dt=6.26228e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000887 m/year, 0.00262 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.484e+05 W, 2.469e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00046
#      Writing particle output:            output-tutorial/particles/particles-00046
#
# *** Timestep 47:  t=1.63198e+09 years, dt=6.78255e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000805 m/year, 0.00245 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.362e+05 W, 2.348e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00047
#      Writing particle output:            output-tutorial/particles/particles-00047
#
# *** Timestep 48:  t=1.70445e+09 years, dt=7.24734e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000741 m/year, 0.00231 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.248e+05 W, 2.236e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00048
#      Writing particle output:            output-tutorial/particles/particles-00048
#
# *** Timestep 49:  t=1.78092e+09 years, dt=7.64683e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000692 m/year, 0.0022 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.144e+05 W, 2.132e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00049
#      Writing particle output:            output-tutorial/particles/particles-00049
#
# *** Timestep 50:  t=1.86091e+09 years, dt=7.99942e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000655 m/year, 0.00211 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -2.048e+05 W, 2.038e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00050
#      Writing particle output:            output-tutorial/particles/particles-00050
#
# *** Timestep 51:  t=1.94389e+09 years, dt=8.29735e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000628 m/year, 0.00205 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.961e+05 W, 1.952e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00051
#      Writing particle output:            output-tutorial/particles/particles-00051
#
# *** Timestep 52:  t=2.02925e+09 years, dt=8.53636e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000608 m/year, 0.00201 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.883e+05 W, 1.874e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00052
#      Writing particle output:            output-tutorial/particles/particles-00052
#
# *** Timestep 53:  t=2.1164e+09 years, dt=8.71563e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000595 m/year, 0.00198 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.812e+05 W, 1.804e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00053
#      Writing particle output:            output-tutorial/particles/particles-00053
#
# *** Timestep 54:  t=2.20484e+09 years, dt=8.84393e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000587 m/year, 0.00195 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.748e+05 W, 1.741e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00054
#      Writing particle output:            output-tutorial/particles/particles-00054
#
# *** Timestep 55:  t=2.29422e+09 years, dt=8.93718e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000583 m/year, 0.00194 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.691e+05 W, 1.684e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00055
#      Writing particle output:            output-tutorial/particles/particles-00055
#
# *** Timestep 56:  t=2.38425e+09 years, dt=9.00305e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000582 m/year, 0.00193 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.639e+05 W, 1.632e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00056
#      Writing particle output:            output-tutorial/particles/particles-00056
#
# *** Timestep 57:  t=2.47468e+09 years, dt=9.043e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000584 m/year, 0.00193 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.592e+05 W, 1.585e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00057
#      Writing particle output:            output-tutorial/particles/particles-00057
#
# *** Timestep 58:  t=2.56524e+09 years, dt=9.05586e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000589 m/year, 0.00193 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.55e+05 W, 1.543e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00058
#      Writing particle output:            output-tutorial/particles/particles-00058
#
# *** Timestep 59:  t=2.65565e+09 years, dt=9.04104e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000596 m/year, 0.00194 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.512e+05 W, 1.506e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00059
#      Writing particle output:            output-tutorial/particles/particles-00059
#
# *** Timestep 60:  t=2.74565e+09 years, dt=9.00003e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000605 m/year, 0.00196 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.477e+05 W, 1.471e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00060
#      Writing particle output:            output-tutorial/particles/particles-00060
#
# *** Timestep 61:  t=2.83501e+09 years, dt=8.9364e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000617 m/year, 0.00198 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.446e+05 W, 1.44e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00061
#      Writing particle output:            output-tutorial/particles/particles-00061
#
# *** Timestep 62:  t=2.92356e+09 years, dt=8.85492e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00063 m/year, 0.002 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.418e+05 W, 1.412e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00062
#      Writing particle output:            output-tutorial/particles/particles-00062
#
# *** Timestep 63:  t=3.01117e+09 years, dt=8.76067e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000644 m/year, 0.00203 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.393e+05 W, 1.387e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00063
#      Writing particle output:            output-tutorial/particles/particles-00063
#
# *** Timestep 64:  t=3.09775e+09 years, dt=8.65836e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00066 m/year, 0.00206 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.37e+05 W, 1.364e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00064
#      Writing particle output:            output-tutorial/particles/particles-00064
#
# *** Timestep 65:  t=3.18327e+09 years, dt=8.55196e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000676 m/year, 0.00209 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.349e+05 W, 1.343e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00065
#      Writing particle output:            output-tutorial/particles/particles-00065
#
# *** Timestep 66:  t=3.26771e+09 years, dt=8.44452e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000693 m/year, 0.00212 m/year
#      Temperature min/avg/max:            273 K, 1930 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.33e+05 W, 1.324e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00066
#      Writing particle output:            output-tutorial/particles/particles-00066
#
# *** Timestep 67:  t=3.3511e+09 years, dt=8.33819e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000711 m/year, 0.00215 m/year
#      Temperature min/avg/max:            273 K, 1930 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.312e+05 W, 1.306e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00067
#      Writing particle output:            output-tutorial/particles/particles-00067
#
# *** Timestep 68:  t=3.43344e+09 years, dt=8.23428e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000729 m/year, 0.00218 m/year
#      Temperature min/avg/max:            273 K, 1930 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.296e+05 W, 1.29e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00068
#      Writing particle output:            output-tutorial/particles/particles-00068
#
# *** Timestep 69:  t=3.51474e+09 years, dt=8.1296e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000748 m/year, 0.00221 m/year
#      Temperature min/avg/max:            273 K, 1930 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.281e+05 W, 1.275e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00069
#      Writing particle output:            output-tutorial/particles/particles-00069
#
# *** Timestep 70:  t=3.59485e+09 years, dt=8.01184e+07 years
#    Solving temperature system... 8 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000768 m/year, 0.00225 m/year
#      Temperature min/avg/max:            273 K, 1930 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.268e+05 W, 1.261e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00070
#      Writing particle output:            output-tutorial/particles/particles-00070
#
# *** Timestep 71:  t=3.67368e+09 years, dt=7.88278e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000788 m/year, 0.00228 m/year
#      Temperature min/avg/max:            273 K, 1930 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.255e+05 W, 1.248e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00071
#      Writing particle output:            output-tutorial/particles/particles-00071
#
# *** Timestep 72:  t=3.75126e+09 years, dt=7.75771e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000809 m/year, 0.00232 m/year
#      Temperature min/avg/max:            273 K, 1930 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.244e+05 W, 1.237e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00072
#      Writing particle output:            output-tutorial/particles/particles-00072
#
# *** Timestep 73:  t=3.82763e+09 years, dt=7.63677e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000831 m/year, 0.00236 m/year
#      Temperature min/avg/max:            273 K, 1930 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.235e+05 W, 1.228e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00073
#      Writing particle output:            output-tutorial/particles/particles-00073
#
# *** Timestep 74:  t=3.90283e+09 years, dt=7.52058e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000854 m/year, 0.00239 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.228e+05 W, 1.22e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00074
#      Writing particle output:            output-tutorial/particles/particles-00074
#
# *** Timestep 75:  t=3.97692e+09 years, dt=7.40897e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000877 m/year, 0.00243 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.222e+05 W, 1.215e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00075
#      Writing particle output:            output-tutorial/particles/particles-00075
#
# *** Timestep 76:  t=4.04994e+09 years, dt=7.302e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 11+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000902 m/year, 0.00246 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.219e+05 W, 1.211e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00076
#      Writing particle output:            output-tutorial/particles/particles-00076
#
# *** Timestep 77:  t=4.12194e+09 years, dt=7.20001e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000927 m/year, 0.0025 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.218e+05 W, 1.21e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00077
#      Writing particle output:            output-tutorial/particles/particles-00077
#
# *** Timestep 78:  t=4.19297e+09 years, dt=7.10268e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.000953 m/year, 0.00253 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.22e+05 W, 1.213e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00078
#      Writing particle output:            output-tutorial/particles/particles-00078
#
# *** Timestep 79:  t=4.26308e+09 years, dt=7.01093e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00098 m/year, 0.00256 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.226e+05 W, 1.218e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00079
#      Writing particle output:            output-tutorial/particles/particles-00079
#
# *** Timestep 80:  t=4.33234e+09 years, dt=6.92608e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00101 m/year, 0.00259 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.235e+05 W, 1.226e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00080
#      Writing particle output:            output-tutorial/particles/particles-00080
#
# *** Timestep 81:  t=4.40083e+09 years, dt=6.84911e+07 years
#    Solving temperature system... 9 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00103 m/year, 0.00263 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.247e+05 W, 1.238e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00081
#      Writing particle output:            output-tutorial/particles/particles-00081
#
# *** Timestep 82:  t=4.46864e+09 years, dt=6.781e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00106 m/year, 0.00266 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.263e+05 W, 1.253e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00082
#      Writing particle output:            output-tutorial/particles/particles-00082
#
# *** Timestep 83:  t=4.53587e+09 years, dt=6.72273e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00109 m/year, 0.00269 m/year
#      Temperature min/avg/max:            273 K, 1931 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.282e+05 W, 1.271e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00083
#      Writing particle output:            output-tutorial/particles/particles-00083
#
# *** Timestep 84:  t=4.60258e+09 years, dt=6.67138e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
# ...
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00203 m/year, 0.00475 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.528e+05 W, 1.487e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00185
#      Writing particle output:            output-tutorial/particles/particles-00185
#
# *** Timestep 186:  t=9.25643e+09 years, dt=3.84231e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00212 m/year, 0.00494 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.554e+05 W, 1.515e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00186
#      Writing particle output:            output-tutorial/particles/particles-00186
#
# *** Timestep 187:  t=9.29333e+09 years, dt=3.69056e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0022 m/year, 0.0051 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.578e+05 W, 1.545e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00187
#      Writing particle output:            output-tutorial/particles/particles-00187
#
# *** Timestep 188:  t=9.32907e+09 years, dt=3.57326e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00227 m/year, 0.00522 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.602e+05 W, 1.575e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00188
#      Writing particle output:            output-tutorial/particles/particles-00188
#
# *** Timestep 189:  t=9.36398e+09 years, dt=3.49185e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00233 m/year, 0.00528 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.625e+05 W, 1.606e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00189
#      Writing particle output:            output-tutorial/particles/particles-00189
#
# *** Timestep 190:  t=9.39844e+09 years, dt=3.44588e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00237 m/year, 0.00529 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.647e+05 W, 1.637e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00190
#      Writing particle output:            output-tutorial/particles/particles-00190
#
# *** Timestep 191:  t=9.43281e+09 years, dt=3.43661e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0024 m/year, 0.00526 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.668e+05 W, 1.667e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00191
#      Writing particle output:            output-tutorial/particles/particles-00191
#
# *** Timestep 192:  t=9.46745e+09 years, dt=3.46425e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00241 m/year, 0.0052 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.687e+05 W, 1.693e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00192
#      Writing particle output:            output-tutorial/particles/particles-00192
#
# *** Timestep 193:  t=9.50243e+09 years, dt=3.49784e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.0024 m/year, 0.00521 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.704e+05 W, 1.717e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00193
#      Writing particle output:            output-tutorial/particles/particles-00193
#
# *** Timestep 194:  t=9.53735e+09 years, dt=3.49241e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00238 m/year, 0.00518 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.718e+05 W, 1.738e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00194
#      Writing particle output:            output-tutorial/particles/particles-00194
#
# *** Timestep 195:  t=9.5725e+09 years, dt=3.51429e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00235 m/year, 0.00513 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.731e+05 W, 1.757e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00195
#      Writing particle output:            output-tutorial/particles/particles-00195
#
# *** Timestep 196:  t=9.60809e+09 years, dt=3.55925e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00231 m/year, 0.00505 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.742e+05 W, 1.775e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00196
#      Writing particle output:            output-tutorial/particles/particles-00196
#
# *** Timestep 197:  t=9.64431e+09 years, dt=3.62219e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00226 m/year, 0.00495 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.754e+05 W, 1.791e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00197
#      Writing particle output:            output-tutorial/particles/particles-00197
#
# *** Timestep 198:  t=9.68126e+09 years, dt=3.69457e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00221 m/year, 0.00484 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.765e+05 W, 1.805e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00198
#      Writing particle output:            output-tutorial/particles/particles-00198
#
# *** Timestep 199:  t=9.71902e+09 years, dt=3.77594e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00216 m/year, 0.00473 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.776e+05 W, 1.819e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00199
#      Writing particle output:            output-tutorial/particles/particles-00199
#
# *** Timestep 200:  t=9.75765e+09 years, dt=3.86366e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00212 m/year, 0.00462 m/year
#      Temperature min/avg/max:            273 K, 1933 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.787e+05 W, 1.831e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00200
#      Writing particle output:            output-tutorial/particles/particles-00200
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      11.2s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system           |       201 |     0.364s |       3.2% |
# | Assemble temperature system      |       201 |     0.761s |       6.8% |
# | Build Stokes preconditioner      |         1 |   0.00765s |         0% |
# | Build temperature preconditioner |       201 |    0.0996s |      0.89% |
# | Initialization                   |         1 |     0.215s |       1.9% |
# | Particles: Advect                |       402 |     0.125s |       1.1% |
# | Particles: Copy                  |       201 |     0.018s |      0.16% |
# | Particles: Generate              |         1 |  0.000635s |         0% |
# | Particles: Initialization        |         1 |  7.09e-05s |         0% |
# | Particles: Initialize properties |         1 |  7.48e-05s |         0% |
# | Particles: Sort                  |       402 |    0.0666s |      0.59% |
# | Postprocessing                   |       201 |      8.74s |        78% |
# | Setup dof systems                |         1 |   0.00262s |         0% |
# | Setup initial conditions         |         1 |   0.00369s |         0% |
# | Setup matrices                   |         1 |   0.00323s |         0% |
# | Solve Stokes system              |       201 |     0.472s |       4.2% |
# | Solve temperature system         |       201 |    0.0821s |      0.73% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 11s
# *** Timestep 201:  t=9.79719e+09 years, dt=3.95336e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00208 m/year, 0.00452 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.798e+05 W, 1.841e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00201
#      Writing particle output:            output-tutorial/particles/particles-00201
#
# *** Timestep 202:  t=9.83759e+09 years, dt=4.04014e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00204 m/year, 0.00443 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.809e+05 W, 1.849e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00202
#      Writing particle output:            output-tutorial/particles/particles-00202
#
# *** Timestep 203:  t=9.87874e+09 years, dt=4.11527e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00201 m/year, 0.00435 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.819e+05 W, 1.854e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00203
#      Writing particle output:            output-tutorial/particles/particles-00203
#
# *** Timestep 204:  t=9.92053e+09 years, dt=4.17869e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00199 m/year, 0.0043 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.828e+05 W, 1.857e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00204
#      Writing particle output:            output-tutorial/particles/particles-00204
#
# *** Timestep 205:  t=9.9628e+09 years, dt=4.22721e+07 years
#    Solving temperature system... 11 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00199 m/year, 0.00426 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.836e+05 W, 1.859e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00205
#      Writing particle output:            output-tutorial/particles/particles-00205
#
# *** Timestep 206:  t=1e+10 years, dt=3.7201e+07 years
#    Solving temperature system... 10 iterations.
#    Solving Stokes system... 12+0 iterations.
#
#    Postprocessing:
#      RMS, max velocity:                  0.00199 m/year, 0.00425 m/year
#      Temperature min/avg/max:            273 K, 1932 K, 3600 K
#      Heat fluxes through boundary parts: 0 W, 0 W, -1.842e+05 W, 1.859e+05 W
#      Writing graphical output:           output-tutorial/solution/solution-00206
#      Writing particle output:            output-tutorial/particles/particles-00206
#
# Termination requested by criterion: end time
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      11.5s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system           |       207 |     0.374s |       3.2% |
# | Assemble temperature system      |       207 |     0.782s |       6.8% |
# | Build Stokes preconditioner      |         1 |   0.00765s |         0% |
# | Build temperature preconditioner |       207 |     0.102s |      0.89% |
# | Initialization                   |         1 |     0.215s |       1.9% |
# | Particles: Advect                |       414 |     0.129s |       1.1% |
# | Particles: Copy                  |       207 |    0.0186s |      0.16% |
# | Particles: Generate              |         1 |  0.000635s |         0% |
# | Particles: Initialization        |         1 |  7.09e-05s |         0% |
# | Particles: Initialize properties |         1 |  7.48e-05s |         0% |
# | Particles: Sort                  |       414 |    0.0684s |      0.59% |
# | Postprocessing                   |       207 |      8.99s |        78% |
# | Setup dof systems                |         1 |   0.00262s |         0% |
# | Setup initial conditions         |         1 |   0.00369s |         0% |
# | Setup matrices                   |         1 |   0.00323s |         0% |
# | Solve Stokes system              |       207 |     0.485s |       4.2% |
# | Solve temperature system         |       207 |    0.0843s |      0.73% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 12s
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=2.5.0-pre&particles=1&sha=d9396f92f&src=code
# -----------------------------------------------------------------------------

# %% [markdown]
# Your results should look something like:
#
# Previous version of ASPECT:
#
# | Ra        | 4000 | 20000 | 100000 | 500000 |
# |-----------|------|-------|--------|--------|
# | end time  |  1.000e+12 |  2.000e+11 | 3.000+10   |  5.000e+09 |
# | viscosity |  1.275e+25 |  2.550e+24 | 5.099e+23  |  1.020e+23 |
# | Refine 3  |  7.142e+04 |  1.198e+05 | 1.71e+05   |  1.61e+05  |
# | Refine 4  |  7.544e+04 |  1.222e+05 | 1.945e+05  |  3.278e+05 |
# | Refine 5  |  7.719e+04 |  1.284e+05 | 2.023e+05  |  3.086e+05 |
#
# ASPECT 2.5.0-pre running on the hub (wallclock seconds):
#
# | Ra        | 4000 | 20000 | 100000 | 500000 |
# |-----------|------|-------|--------|--------|
# | end time  |  4.000e+10 |  2.000e+10 | 1.00e+10   |  2.000e+09 |
# | viscosity |  1.275e+25 |  2.550e+24 | 5.099e+23  |  1.020e+23 |
# | Refine 3 | 7.098e+04 (4s) | 1.2e+05 (8s) | 1.842e+05 (11.5s) | 1.835+05 (6s)|
# | Refine 4 | 7.756e+04 (17s) | 1.271e+05 (33s) | 1.992e+05 (s) | 2.825+05 (19s)|
# | Refine 5 | 7.94e+04 (99s)| 1.301e+05 (184s)| 2.018e+05 (s)|2.911e+05 (94s) |
#
#
# Run the next cell to plot these results.
#
# $Ra^{1/3}$ is plotted for comparison.

# %%
import numpy as np
import matplotlib
matplotlib.rcParams['figure.figsize']=(10,10)
import matplotlib.pyplot as plt

from matplotlib.ticker import FormatStrFormatter
# Remember to plot it in the notebook.
# %matplotlib inline

# Hand assign these arrays
xdata = np.array([4000, 20000, 100000, 500000])                     # Rayleigh Number

ydata = np.array ([ 
       [9.524e+04,1.629e+05,2.785e+05,4.762e+05],        # Rayleigh 1/3
#       [7.142e+04,1.198e+05,1.71e+05,1.61e+05],          # Refinement level 3
#       [7.544e+04,1.222e+05,1.945e+05,3.278e+05],        # Refinement level 4
#       [7.719e+04,1.284e+05,2.023e+05,3.086e+05] ])     # Refinement level 5
       [7.098e+04,1.2e+05,1.842e+05, 1.835e+05],
       [7.756e+04,1.271e+05,1.992e+05,2.825e+05],
       [7.94e+04,1.301e+05,2.018e+05,2.911e+05]
       ])
# Assign labels to the legend
leg=['Ra 1/3','Level 3','Level 4', 'Level 5']
# Assign colors for the lines. There are more colors specified here then .
colors = ['red', 'blue', 'green', 'orange', 'purple', 'pink']

fig = plt.figure( figsize = (10,5))
ax = fig.add_subplot(111)

# now let's trying plotting a simple log-log x-y graph looping over the array
for y, color in zip(ydata, colors):
    ax.loglog(xdata, y, linewidth=2.0, color=color)

ax.set_xlabel('Ra',fontsize=16)
ax.set_ylabel('Nu',fontsize=16)
ax.set_title('Nusselt-Rayleigh Relationship',fontsize=20)
ax.legend(leg,loc='lower right')



ax.set_xlim([1000, 1000000])
ax.set_ylim([5.0e+04, 1.0e+06])

plt.show()

# %% [markdown]
# **Exercise:** Do we observe the correct Rayleigh-Nusselt this in our simulation?
#
# **Exercise:** Which is better, REFINEMENT=3 or REFINEMENT=5?
#
# **Exercise:** Why?
#
# **Exercise:** Should we always pick the largest possible refinement value?

# %% [markdown]
# ### Time to Play
#
# Below is a few suggested exercises for you to play in this notebook on your own.
#
# Cut and paste from above to the code cell below.
#
# > **Exercise:** Plot the Nusselt number over time.
#
# > **Exercise:** Change the geometry.
#
# > **Exercise:** Change boundary conditions.
#
# > **Exercise:** Try another cookbook!

# %% [markdown]
# ## 4.0 Good Things to Know
#
#
# ### 4.1 Governing Equations
# ASPECT solves a system of equations in a 2- or 3-dimensional
# domain $\Omega$ that describes the motion of a highly viscous fluid driven
# by differences in the gravitational force due to a density that depends on
# the temperature.
#
# Specifically, we consider the following set of equations for velocity $\mathbf
# u$, pressure $p$ and temperature $T$, as well as a set of advected quantities
# $c_i$ that we call <em>compositional fields</em>:
#
# (1) Momentum equation:
# \begin{align}
#     -\nabla \cdot \left[2\eta \left(\varepsilon(\mathbf u)
#                                   - \frac{1}{3}(\nabla \cdot \mathbf u)\mathbf 1\right)
#                 \right] + \nabla p &=
#   \rho \mathbf g
# \end{align}
#  (2) Conservation of mass:
# \begin{align}
#     \nabla \cdot (\rho \mathbf u) &= 0
# \end{align}
#  (3) Conservation of energy:
# \begin{align}
# \rho C_p \left(\frac{\partial T}{\partial t} + \mathbf u\cdot\nabla T\right)
#   - \nabla\cdot k\nabla T
#   &=
#   \rho H
#   \notag
#   \\
#   &\quad
#   +
#   2\eta
#   \left(\varepsilon(\mathbf u) - \frac{1}{3}(\nabla \cdot \mathbf u)\mathbf 1\right)
#   :
#   \left(\varepsilon(\mathbf u) - \frac{1}{3}(\nabla \cdot \mathbf u)\mathbf 1\right)
#   \\
#   &\quad
#   +\alpha T \left( \mathbf u \cdot \nabla p \right)
#   \notag
#   \\
#   &\quad
#   + \rho T \Delta S \left(\frac{\partial X}{\partial t} + \mathbf u\cdot\nabla X\right)
#   &
#   & \textrm{in $\Omega$}
# \end{align}
# (4) Advection of compositional fields:
# \begin{align}
# \frac{\partial c_i}{\partial t} + \mathbf u\cdot\nabla c_i
#   &=
#   q_i
#   &
#   & \textrm{in $\Omega$},
#   i=1\ldots C
# \end{align}
#
# In this set of equations, (1) and (2)
# represent the compressible Stokes equations in which $\mathbf u=\mathbf
# u(\mathbf x,t)$ is the velocity field and $p=p(\mathbf x,t)$ the pressure
# field. Both fields depend on space $\mathbf x$ and time $t$. Fluid flow is
# driven by the gravity force that acts on the fluid that is proportional to
# both the density of the fluid and the strength of the gravitational pull.
#
# Coupled to this Stokes system is equation (3) for the
# temperature field $T=T(\mathbf x,t)$ that contains heat conduction terms as
# well as advection with the flow velocity $\mathbf u$. The right hand side
# terms of this equation correspond to:
# * internal heat production, e.g. radioactive decay;
# * shear heating;
# * adiabatic heating (compression of material); and
# * latent heat (phase change).
#
# Equation (4) describes
# the evolution of additional fields that are transported along with the
# velocity field $\mathbf u$ and may react with each other and react to other
# features of the solution but do not diffuse. We call these fields, $c_i$,
# <em>compositional fields</em> although they can also be used for other
# purposes than just tracking chemical compositions.
#
# ### 4.2  The .prm file
# example file is convection_box.prm
#
# #### subsection Geometry model
#
# ASPECT has many built in geometry models such as “box” and “shell” and "chunk".
#
# A box is a rectangle in 2-D and a cuboid in 3-D.
#
# In your .prm file,
# * X extent is width
# * Y extent is depth
#
# Units of length is meter.
#
# #### subsection Initial temperature model
# ASPECT has built in initial condition models to specify the temperature initial conditions and framework for users to implement custom initial condition models.
#
# Function lets us specify the intial temperature as a mathematical formula, with user defined constants.
#
# In the example here, a sinusoidal perturbation of a linear temperature profile is specified.
#
# #### subsection Boundary temperature model
#
# The boundary temperature of your box can be specified using Top, Bottom, Left, and Right.
#
# Temperatures are in K.
#
# #### subsection Model settings
# Each geometry model has a set of “boundary indicators” that identifies each boundary in the model.
#
# In the 2D box model, the boundary identification is Left or 0, Right or 1, Bottom or 2, Top or 3.
#
# In the example here:
# * The temperature on the bottom and top boundaries is fixed.
# * All four sides of the box have only a tangential component to the velocity (zero normal component).
#
# You can set adiabatic, shear, or radiogenic heating in this subsection as well.
#
# #### subsection Material model
# ASPECT provides various built in material models and a framework for users to implement custom material models.
#
# In the example here, the built in simple material model is used:
# \begin{align}
#   \rho( T) = \rho_0 ( 1 - \beta ( T - T_{ref})
#   \eta(T) = \eta_0\epsilon^{\eta_T \Delta T/T_{ref}}
# \end{align}
#
# where $\eta_0$ is set by the VISCOSITY parameter, $\rho_0$ is the default value $3300kg/m^3$, and
# $\eta_T = 1$ (viscosity does not depend on the composition).
#
# There are several other parameters which control reference density, temperature dependence of
# viscosity, etc. These have default values shown in Section 4.3.
#
# #### subsection Mesh refinement
# Initial global refinement specifies the "grid spacing".
#
# In the example here:
# * Intial global refinement was set to 4 corresponding to a 16x16 grid. Setting refinement to 3 corresponds to an 8x8 grid; Setting refinement to 16 correspond to a 32x32 grid.
# * Adaptive mesh refinement is turned off.
#
# #### subsection Postprocess
# This section of the parameter file specifies how to analyze the data that has been generated.
#
# In the example here:
# * Post processors include velocity, temperature, heat flux statistics, and visualization.
# * Graphical output is generated every 0.01 years (simulation time!)
#
#
# ### 4.3 Default Values
#
# ASPECT uses SI units (MKS):
# * $t$ time is internally calculated in seconds. Exported in years.
# * $\bf{u}$ velocity $m/s$
# * $p$ pressure Pa
# * $T$ temperature K
# * $\epsilon(\bf{u})$ strain rate $1/s$
# * $\eta$ viscosity $Pa \cdot s$
# * $\rho$ density $kg/m^3$
# * g gravity $m/s^2$
# * $C_p$ specific heat capacity $J/kg \cdot K$
# * $\kappa$ thermal conductivity $W/m \cdot K$
# * $\it{H}$ intrinsic specific heat production $W/kg$
#
# Default values:
# * $\rho_0 = 3300$
# * $g=9.8$
# * $\alpha = 2 \times 10^{-5}$
# * $\Delta T = 3600-273 = 3327 $
# * $D = 3 \times 10^6$
# * $k = 4.7$
# * $c_p = 1250 $
# * $\kappa = {k \over {\rho_0c_p}} = 1.1394 \times 10^{-6} $

# %% [markdown]
# ## ! LAST THING ! Reproducibility and Credit
#
# Support reproducibility of your results.
#
# You can do this in your publications by citing:
# * the version of the code used,
# * where the code can be found, and
# * input and output files repository.
#
# > Consult your institution and/or publisher for repository recommendations.
# > Still do not know what to use? Check out zenodo.org.  CIG maintains a Zenodo Community - Computational Infrastructure for Geodynamics.  Join the community to improve discoverability of your work.
#
# Many researchers have contributed a large amount of time and effort to developing ASPECT for the community.  Help them in their careers by citing ASPECT.
#
# For the latest citation information, go to:
# > http://aspect.dealii.org/publications.html
#
# For full citation and attribution information see:
# > https://geodynamics.org/abc

# %% [markdown]
# ## A. Running in Docker
# A. Install Docker
#
# B. Download the docker image
# > docker pull tjhei/aspect-jupyter
#
# 1. Start Docker
# 2. In a terminal window, navigate to directory where your model input is located:
# >	cd my_directory/ModelInput
# 3. Load the Jupyter extension for widgets:
# >jupyter nbextension enable widgetsnbextension --py --sys-prefix
# 4. Spin up Timo’s container with Jupyter notebooks and map your current working directory as input:
# >	docker run -it -v "$(pwd):/home/dealii/aspect/model_input:ro" -d -p 8888:8888 --name tmpnb-aspect-jupyter tjhei/aspect-jupyter start-notebook.sh --NotebookApp.token=' '
# 5. In a browser, type:
# >	http://localhost:8888/tree?
# 6. Upload this notebook and the image files.
#
# Remember you are now running in a Docker container and NOT your desktop.
#
# ** Common problems: **
#
# 	unexpected error address already in use.
# 	change your local host address 8887:8888
# 	change this to 8887 in step 5
#
# You have to remove (or rename) that container to be able to reuse that name.
# Easiest solution (somewhat heavy handed) stop your container, prune, and check.
#
# > docker stop CONTAINER_ID
#
# > docker container prune
#
# > docker ps -a
#
#  ## B. Packages install
#
# The heat flux slider requires the installation of two additional packages.
#
# ** Adding Jupyter widgets **
#
# You should have added this in Step 3 above:
# > jupyter nbextension enable widgetsnbextension --py --sys-prefix
#
# ** installing tables **
# > conda install tables

# %% [markdown]
# ## C. Historical Note
#
# This notebook was orginally developed for ASPECT v1.5.0 in 2017.
#
# The original results for the Nusselt-Rayleigh relationship is shown below.
#
# Note that subsequent releases include changes to the .prm file and solver improvements.
#
#
# | Ra        | 4000 | 20000 | 100000 | 500000 |
# |-----------|------|-------|--------|--------|
# | end time  |  1.000e+12 |  2.000e+11 | 3.000+10   |  5.000e+09 |
# | viscosity |  1.275e+25 |  2.550e+24 | 5.099e+23  |  1.020e+23 |
# | Refine 3  |  7.142e+04 |  1.198e+05 | 1.71e+05   |  1.61e+05  |
# | Refine 4  |  7.544e+04 |  1.222e+05 | 1.945e+05  |  3.278e+05 |
# | Refine 5  |  7.719e+04 |  1.284e+05 | 2.023e+05  |  3.086e+05 |

# %%
import numpy as np
import matplotlib
matplotlib.rcParams['figure.figsize']=(10,10)
import matplotlib.pyplot as plt

from matplotlib.ticker import FormatStrFormatter
# Remember to plot it in the notebook.
# %matplotlib inline

# Hand assign these arrays
xdata = np.array([4000, 20000, 100000, 500000])                     # Rayleigh Number

ydata = np.array ([ 
       [9.524e+04,1.629e+05,2.785e+05,4.762e+05],        # Rayleigh 1/3
       [7.142e+04,1.198e+05,1.71e+05,1.61e+05],          # Refinement level 3
       [7.544e+04,1.222e+05,1.945e+05,3.278e+05],        # Refinement level 4
       [7.719e+04,1.284e+05,2.023e+05,3.086e+05] ])     # Refinement level 5
       
# Assign labels to the legend
leg=['Ra 1/3','Level 3','Level 4', 'Level 5']
# Assign colors for the lines. There are more colors specified here then .
colors = ['red', 'blue', 'green', 'orange', 'purple', 'pink']

fig = plt.figure( figsize = (10,5))
ax = fig.add_subplot(111)

# now let's trying plotting a simple log-log x-y graph looping over the array
for y, color in zip(ydata, colors):
    ax.loglog(xdata, y, linewidth=2.0, color=color)

ax.set_xlabel('Ra',fontsize=16)
ax.set_ylabel('Nu',fontsize=16)
ax.set_title('Nusselt-Rayleigh Relationship',fontsize=20)
ax.legend(leg,loc='lower right')

ax.set_xlim([1000, 1000000])
ax.set_ylim([5.0e+04, 1.0e+06])

plt.show()

# %%
# !pwd
# !ls
# Out:
# /home/geodynamics/ljhwang/ASPECT-Jupyter/Notebook
# ASPECT_Jupyter.ipynb  modularity1.png  output-convection-box2  TempInit.jpg
# aspect_www_small.jpg  modularity2.png  TempFinal.jpg
